# %% [markdown]
# # Лабораторна робота 1
# ## обраний датасет можна завантажити за посиланням (ось [тут](https://www.kaggle.com/datasets/clmentbisaillon/fake-and-real-news-dataset))

# %%
import pandas as pd
import matplotlib.pyplot as plt
import re
import string
import sys
from unicodedata import category
import nltk as nlp
import contractions
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from pandarallel import pandarallel
from wordcloud import WordCloud
from multiprocessing import cpu_count
import numpy as np
from tqdm import tqdm
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from gensim.models import Word2Vec, Doc2Vec
from gensim.models.doc2vec import TaggedDocument
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, confusion_matrix, ConfusionMatrixDisplay
from typing import List
from scipy.spatial.distance import cosine
from transformers import AutoTokenizer, AutoModelForTokenClassification
from transformers import pipeline

# %%
fake_dataset = pd.read_csv('../data/lab1/Fake.csv')
fake_dataset['label'] = 1
fake_dataset.head(5)
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  label
# 0  December 31, 2017      1
# 1  December 31, 2017      1
# 2  December 30, 2017      1
# 3  December 29, 2017      1
# 4  December 25, 2017      1

# %%
true_dataset = pd.read_csv('../data/lab1/True.csv')
true_dataset['label'] = 0
true_dataset.head(5)
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date  label
# 0  December 31, 2017       0
# 1  December 29, 2017       0
# 2  December 31, 2017       0
# 3  December 30, 2017       0
# 4  December 29, 2017       0

# %%
df = pd.concat([true_dataset, fake_dataset])
df = (
    df
    .sample(frac=1)
    .reset_index(drop=True)
)
df.head(10)
# Out:
#                                                title  \
# 0  Factbox: Trump on Twitter (Sept 18) - U.S. Air...
# 1  Drug enforcement chief criticizes Trump in ema...
# 2  Trump to sign Russia sanctions, Moscow retaliates
# 3  Caught up in Catalan crisis, Belgian PM urges ...
# 4   TN First Sgt. Cites ‘Toxic Leadership’ In Cur...
# 5       Boiler Room #102 – Tales From The Black Pill
# 6  WATCH MAJOR MOMENT President-elect Trump And E...
# 7  Clinton server tech told FBI of colleagues' wo...
# 8  DEMOCRAT ALAN DERSHOWITZ Calls Out Court’s Rul...
# 9  BREAKING…AMERICA WAS PUNKED! No Direct Ties Be...
#
#                                                 text          subject  \
# 0  The following statements were posted to the ve...     politicsNews
# 1  WASHINGTON (Reuters) - The U.S. Drug Enforceme...     politicsNews
# 2  WASHINGTON/MOSCOW (Reuters) - U.S. President D...     politicsNews
# 3  BRUSSELS (Reuters) - Belgium s prime minister,...        worldnews
# 4  After more than 20 years of service within the...             News
# 5  Tune in to the Alternate Current Radio Network...          US_News
# 6                                                     Government News
# 7  NEW YORK (Reuters) - A technician hired by Hil...     politicsNews
# 8                                                            politics
# 9  Could this be the biggest FAKE NEWS story of 2...        left-news
#
#                   date  label
# 0  September 18, 2017       0
# 1      August 1, 2017       0
# 2       July 28, 2017       0
# 3    November 8, 2017       0
# 4        June 24, 2016      1
# 5       March 24, 2017      1
# 6         Jan 19, 2017      1
# 7  September 24, 2016       0
# 8         Mar 20, 2017      1
# 9         Jan 11, 2017      1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44898 entries, 0 to 44897
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    44898 non-null  object
#  1   text     44898 non-null  object
#  2   subject  44898 non-null  object
#  3   date     44898 non-null  object
#  4   label    44898 non-null  int64
# dtypes: int64(1), object(4)
# memory usage: 1.7+ MB

# %%
df['text'].duplicated().sum()
# Out:
# 6252

# %%
df['text'].isna().sum()
# Out:
# 0

# %%
df.drop_duplicates(subset=['text'], inplace=True)
df['text'].duplicated().sum()
# Out:
# 0

# %%
df['label'].value_counts()
# Out:
# label
# 0    21191
# 1    17455
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (38646, 5)

# %%
df.loc[0, 'text']
# Out:
# 'The following statements\xa0were posted to the verified Twitter accounts of U.S. President Donald Trump, @realDonaldTrump and @POTUS.  The opinions expressed are his own.\xa0Reuters has not edited the statements or confirmed their accuracy.  @realDonaldTrump : - Happy 70th Birthday @USAirForce!  [0914 EDT] - Happy 70th Birthday @CIA!  [0916 EDT] -- Source link: (bit.ly/2jBh4LU) (bit.ly/2jpEXYR) '

# %%
df['text_len'] = df['text'].str.len()
df.head(5)
# Out:
#                                                title  \
# 0  Factbox: Trump on Twitter (Sept 18) - U.S. Air...
# 1  Drug enforcement chief criticizes Trump in ema...
# 2  Trump to sign Russia sanctions, Moscow retaliates
# 3  Caught up in Catalan crisis, Belgian PM urges ...
# 4   TN First Sgt. Cites ‘Toxic Leadership’ In Cur...
#
#                                                 text       subject  \
# 0  The following statements were posted to the ve...  politicsNews
# 1  WASHINGTON (Reuters) - The U.S. Drug Enforceme...  politicsNews
# 2  WASHINGTON/MOSCOW (Reuters) - U.S. President D...  politicsNews
# 3  BRUSSELS (Reuters) - Belgium s prime minister,...     worldnews
# 4  After more than 20 years of service within the...          News
#
#                   date  label  text_len
# 0  September 18, 2017       0       392
# 1      August 1, 2017       0      2569
# 2       July 28, 2017       0      5193
# 3    November 8, 2017       0      2261
# 4        June 24, 2016      1      2869

# %%
plt.hist(df.loc[df.label == 1, 'text_len'], bins=30, alpha=0.5, label='Fake')
plt.hist(df.loc[df.label == 0, 'text_len'], bins=30, alpha=0.5, label='Real')

plt.xlabel('Text Length')
plt.ylabel('Frequency')
plt.legend(loc='upper right')
plt.title('Before')

plt.show()

# %%
print(df[df['text_len'] < 50].shape)
df[df['text_len'] > 10_000].shape
# Out:
# (143, 6)
# (204, 6)

# %%
df = df[df['text_len'] > 50]
df = df[df['text_len'] < 10_000]
df.reset_index(drop=True, inplace=True)
df.shape
# Out:
# (38298, 6)

# %%
plt.hist(df.loc[df.label == 1, 'text_len'], bins=30, alpha=0.5, label='Fake')
plt.hist(df.loc[df.label == 0, 'text_len'], bins=30, alpha=0.5, label='Real')

plt.xlabel('Text Length')
plt.ylabel('Frequency')
plt.legend(loc='upper right')
plt.title('After')

plt.show()

# %%
STOPWORDS = set(stopwords.words('english'))
LEMMATIZER = WordNetLemmatizer()

pandarallel.initialize(progress_bar=True, verbose=1)

# %%
def processing_text(text: str, punctuation: str, remove_stop_words: bool = True) -> str:
    t = contractions.fix(text)
    t = t.lower()
    t = t.translate(str.maketrans('', '', punctuation))
    t = ' '.join([word for word in t.split() if not re.search('\d', word)])
    if remove_stop_words:
        t = ' '.join([word for word in t.split() if word not in STOPWORDS])
    t = ' '.join(list(filter(lambda x: len(x) > 5, [LEMMATIZER.lemmatize(word) for word in t.split()])))
    t = t.strip()
    return t

# %%
chrs = (chr(i) for i in range(sys.maxunicode + 1))
punctuation = set(c for c in chrs if category(c).startswith("P")) | set(string.punctuation)
punctuation=''.join(punctuation)
punctuation
# Out:
# '⸗𑩁𞥟⸚᯾𑙣％⦉⸓﹪‰𑙢＇※𑈹⹎𑗊“಄෴꧞༌＼꫟꩞﹔𑩂⁘】‴"﹒׳؊𑱅׆𑙬︔᳅⁛﹆༆（𑙠𑩄⦍⸍༻⸸𑂿𖬺〈𑙫‸꡴᭟⟧⹉⧽᠉~᪠⁑༎၍᠆⸷꓾᪭𑈻𑗍·⸁𑙧⸪𑨿᭜⁈〟｛﴾࿑❪𐮚𑿿’⦅⸣𑗇𐫱܌࠷｣᨞᭞⁆٬᯿⸱〞・᰼᰿＃᚛𐽘⟪「⹁｝՚❩⹏⟨﹙{⟬﹫॥꧟࿔‑‧／՜⟫⦄⹃)𑑋、⹒｢𖩯᰽］‗𒑰𑈽〕》܇܋‥𑱱‡٫។⹊｠？𐽙‐᚜𑪜𑗓︳⁃።𖫵⧚′⸏❰॰᠅⁜𑁊‖–៙؛꩜⸆𐬺𑗋꣹٪⹍⸛𑱁,꧈」᠀꣺𑗎‼⧛𐽕࠽᪬﹛𐄂︑︰༉𒑲꛴𖺘𖿢᠇𐩖⸙⸎𑂻𑜼𑜾︐⸶𑙥܂༔⳼⹀𑗄܃〝﹝࠱᛬᜶𐩗𑅴𐫰៚᱿⸖⦋࠵࿐𑙤.⁉″‷⟅!‟𐺭࠾𑇛๏᳀𑅀𑊩⁕⦈⦆﹑＊#`။᠊৽:𐫳－᯽꤮܍⸒⸈᪣⸬⸳𝪈𑂾‶❲₎𒑱𐤿⸠﹖𐬼⌋‹⁊𐩿𑗅༑†𑗏׀܅𐏐〰᥅𐩑𑻸⁝𑙃―𑑚⦘꧂︖՛꙳᰾』𑅂᙮𑈼﹨؟⁌⦌៕꩝︙〗⵰|⹇⸹܈⦕꛶࠶׃꛵᳂❯꧄𑗌࠳᛭❭-٭꛳⦔꧋⁁﹀𑜽𖬸﹅៘꡵﹚⦎𐬾᠁𑅵᠈᭠⹅}⹈་𐬻︕︘﹠՟꛷𐄀𑇈࠺𑈺𑑛?𑱄᳄𑅃⸤‱𑑏›⦓⌈【︲𝪊᪤፨⁚⁗゠⳿꥟؉⁍𝪇『⸨⁇𐫶𑑍⸔﹘𑪛๚[꣼❴𖬻%𑗈᪥»߹⦑꯫𑱂᐀𑩀࠴༊⸂<⸋︶‘❳𑗖፡⦒𝪉𑗐᪨*၊❫︿$⸩₍꧉《𑓆𑗒𑪠⸼𐬹⦃𑇞⸻𑪟⸃𑥄࠰⦗﹈。𐫵߷⁅⁓﹂❨𑅁⁂⁐࿒︼𒑳⸉᯼፣𑇇፦︽⟮︒⳾⹄⳹‚❵⸦꓿;︾𑪢᪪︸༼𑙡᭛᳁౷‿＆𑁈𑂼𞥞𐮜⸝⁙꧊⹋𐬽𑑝𑧢𖺙⸡؍𑗗༇𛲟𑪞𐩔⸕﹇؞･፧،，꫰︺⹂⁔࿙•܉⸢︱_᠂࿓‽⧘꙾꡷𑑌𑱰︷﹁⁾：⟩｟𑗆⁖꧃࠼⸵𑠻༄꛲𑪡᠃𖺚⸅𐎟‵𐩐⦊𑱃⧼𑇍＿༒᭚〖﹕⸄꣎᭝⌊﹋๛𑁇𑙨𑥅᪢᰻”(︓❬⸀︹⟯܊〽꘎𐬿𑁍𑩅꩟᥄𖬷၏‣‾❱༺⸌—⸭𑈸𐩒꧍〈⹌﹟𑙪\\¿𐩘⁋𑗉；꫞⦖᠄꣸𐕯❮𑗃⁎𝪋⦏᳃꣏〘࡞꘏᜵⹆﹍𐮛𖬹﹜«［⁏⟦‒꧌𖺗܀𑃁𑗑⟭𑇅〜．⁀𐮙𐫲§︻༐፥𑗁፠﹉𑁉+⸮꘍𑗕]༏⸐⸲‛⸟﹣⧙꫱꤯𑗔𑙩։᳆੶﴿𐽗=𐩓𐩕𑩃।¶࠸>…𖩮﹄܄࠻𑙁@၎᪫⸇·〉﹃᳇꡶⟆֊⦇⳺﹌𐡗\'｡！․״„﹗՝𒑴꧇﹡）𐄁𑪚⸾﹎､𑙂།&︵⸑¡＂〚𑇟𑇝꧅〉՞𑙦𑻷၌꧆፤៖⦐⸘⌉/︗܆𑁋𑗂᛫࠲૰⸊𑥆⸧྅^༽𑁌︴߸𐽖⸺࿚;〛⸿⁽܁࠹᪩⁞჻﹞༈⸰〔᱾᪡〙＠⸜﹏⸫۔⸴𑃀־꧁᨟〃𐫴𑑎﹐⸽﹊𑇆𑩆⸥༅⸞𐤟᪦⳻᳓𖭄'

# %%
# %%time

df['text_clean'] = df['text'].parallel_apply(lambda x: processing_text(x, punctuation))
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=9575), Label(value='0 / 9575'))), …
# CPU times: user 620 ms, sys: 161 ms, total: 780 ms
# Wall time: 24.9 s

# %%
df[['text', 'text_clean']].head(5)
# Out:
#                                                 text  \
# 0  The following statements were posted to the ve...
# 1  WASHINGTON (Reuters) - The U.S. Drug Enforceme...
# 2  WASHINGTON/MOSCOW (Reuters) - U.S. President D...
# 3  BRUSSELS (Reuters) - Belgium s prime minister,...
# 4  After more than 20 years of service within the...
#
#                                           text_clean
# 0  following statement posted verified twitter ac...
# 1  washington reuters enforcement administration ...
# 2  washingtonmoscow reuters president donald legi...
# 3  brussels reuters belgium minister battling con...
# 4  service within national dennis carter submitte...

# %%
df.loc[0, 'text_clean']
# Out:
# 'following statement posted verified twitter account president donald realdonaldtrump opinion expressed reuters edited statement confirmed accuracy realdonaldtrump birthday usairforce birthday source'

# %%
fake_words = " ".join(df.loc[df.label == 1, 'text_clean'])

plt.figure(figsize=(20, 16))
wc = WordCloud(width=1400 , height=800 , max_words=3000).generate(fake_words)
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 1399.5, 799.5, -0.5)

# %%
true_words = " ".join(df.loc[df.label == 0, 'text_clean'])

plt.figure(figsize=(20, 16))
wc = WordCloud(width=1400 , height=800 , max_words=3000).generate(true_words)
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 1399.5, 799.5, -0.5)

# %%
# %%time
#BOW model for features

bow_vectorizer = CountVectorizer(lowercase=False, ngram_range=(1, 2), max_features=1000)
bow = bow_vectorizer.fit_transform(df['text_clean'])
bow.shape
# Out:
# CPU times: user 15.2 s, sys: 339 ms, total: 15.5 s
# Wall time: 15.5 s
# (38298, 1000)

# %%
# %%time
#tfidf model for features

tfidf_vectorizer = TfidfVectorizer(lowercase=False, ngram_range=(1, 2), max_features=1000)
tfidf = tfidf_vectorizer.fit_transform(df['text_clean'])
tfidf.shape
# Out:
# CPU times: user 15.2 s, sys: 319 ms, total: 15.5 s
# Wall time: 15.5 s
# (38298, 1000)

# %%
# %%time
#word2vec model for features

RS = 47
tokenized_text = df['text_clean'].apply(lambda x: x.split())

w2v_model = Word2Vec(
     tokenized_text,
     vector_size=200,
     min_count=10,
     window=5,
     epochs=20,
     sg=1,
     sample=6e-5,
     alpha=0.03,
     min_alpha=0.0007,
     negative=10,
     seed=RS,
     workers=cpu_count()
)

w2v_model.build_vocab(tokenized_text)

w2v_model.train(tokenized_text, total_examples=w2v_model.corpus_count, epochs=w2v_model.epochs)
# Out:
# CPU times: user 1h 12min 58s, sys: 11.8 s, total: 1h 13min 10s
# Wall time: 10min 26s
# (58734099, 100506220)

# %%
w2v_model.wv.index_to_key[:50]
# Out:
# ['president',
#  'republican',
#  'people',
#  'reuters',
#  'donald',
#  'government',
#  'clinton',
#  'country',
#  'united',
#  'election',
#  'campaign',
#  'official',
#  'american',
#  'washington',
#  'former',
#  'security',
#  'leader',
#  'national',
#  'percent',
#  'democrat',
#  'million',
#  'presidential',
#  'political',
#  'support',
#  'administration',
#  'statement',
#  'hillary',
#  'senate',
#  'police',
#  'democratic',
#  'russia',
#  'including',
#  'office',
#  'policy',
#  'medium',
#  'member',
#  'attack',
#  'foreign',
#  'minister',
#  'according',
#  'candidate',
#  'called',
#  'military',
#  'federal',
#  'saying',
#  'tuesday',
#  'department',
#  'america',
#  'public',
#  'report']

# %%
len(w2v_model.wv)
# Out:
# 20586

# %%
w2v_model.wv.most_similar(positive=['history'], topn=10)
# Out:
# [('modern', 0.6320871114730835),
#  ('america', 0.5228592157363892),
#  ('remember', 0.4992768466472626),
#  ('especially', 0.48579367995262146),
#  ('racist', 0.48401883244514465),
#  ('probably', 0.4758264422416687),
#  ('moment', 0.468784362077713),
#  ('entire', 0.46850091218948364),
#  ('though', 0.467699259519577),
#  ('reminder', 0.4642930328845978)]

# %%
#cross one out
w2v_model.wv.doesnt_match(['country', 'people', 'donald'])
# Out:
# 'donald'

# %%
w2v_model.wv.most_similar(positive=["people", "income"], negative= ["america"], topn=3)
# Out:
# [('deduction', 0.48366865515708923),
#  ('highincome', 0.46492964029312134),
#  ('itemized', 0.4643110930919647)]

# %%
w2v_model.wv['america'].shape
# Out:
# (200,)

# %%
def word_vector(tokens, size):
    vec = np.zeros(size).reshape((1, size))
    count = 0
    for word in tokens:
        try:
            vec += w2v_model.wv[word].reshape((1, size))
            count += 1
        except KeyError:
            continue
    if count != 0:
        vec /= count
    return vec

# %%
wordvec_arrays = np.zeros((len(tokenized_text), 200))
for i in range(len(tokenized_text)):
    wordvec_arrays[i,:] = word_vector(tokenized_text[i], 200)
wordvec_arrays.shape
# Out:
# (38298, 200)

# %%
# %%time
#doc2vec model for features

tagged_data = [TaggedDocument(words=doc.split(), tags=[i]) for i, doc in enumerate(df['text_clean'])]

d2v_model = Doc2Vec(
    tagged_data,
    vector_size=200,
    window=5, # width of the context window
    epochs=20,
    negative=10, # if > 0 then negative sampling will be used
    min_count=10, # Ignores all words with total frequency lower than 10.
    workers=cpu_count(),
    alpha=0.03,
    min_alpha=0.0007,
    sample=6e-5,
    seed=RS
)

d2v_model.build_vocab([i for i in tqdm(tagged_data)])

d2v_model.train(tagged_data, total_examples=d2v_model.corpus_count, epochs=d2v_model.epochs)
# Out:
# 100%|██████████| 38298/38298 [00:00<00:00, 2941304.35it/s]
# CPU times: user 15min 56s, sys: 45.4 s, total: 16min 41s
# Wall time: 6min 15s

# %%
docvec_arrays = np.zeros((len(tagged_data), 200))
for i in range(len(tagged_data)):
    docvec_arrays[i,:] = d2v_model.dv[i].reshape((1, 200))
docvec_arrays.shape
# Out:
# (38298, 200)

# %%
tagged_data[0]
# Out:
# TaggedDocument(words=['following', 'statement', 'posted', 'verified', 'twitter', 'account', 'president', 'donald', 'realdonaldtrump', 'opinion', 'expressed', 'reuters', 'edited', 'statement', 'confirmed', 'accuracy', 'realdonaldtrump', 'birthday', 'usairforce', 'birthday', 'source'], tags=[0])

# %%
def print_conf_matrix(y, y_pred):
    cm = confusion_matrix(y, y_pred)

    cm_display = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0, 1])

    cm_display.plot()
    plt.show()

# %%
xtrain_bow, xtest_bow, ytrain, ytest = train_test_split(bow, df['label'], random_state=RS, test_size=0.3)

# %%
rf = RandomForestClassifier(n_estimators=100, n_jobs=cpu_count(), random_state=RS).fit(xtrain_bow, ytrain)
prediction = rf.predict(xtest_bow)
f1_score(ytest, prediction)
# Out:
# 0.9950258460938262

# %%
print_conf_matrix(ytest, prediction)

# %%
xtrain_tfidf = tfidf[ytrain.index]
xtest_tfidf = tfidf[ytest.index]

rf = RandomForestClassifier(n_estimators=100, n_jobs=cpu_count(), random_state=RS).fit(xtrain_tfidf, ytrain)
prediction = rf.predict(xtest_tfidf)
f1_score(ytest, prediction)
# Out:
# 0.9948307812347605

# %%
print_conf_matrix(ytest, prediction)

# %%
xtrain_docvec = docvec_arrays[ytrain.index]
xtest_docvec = docvec_arrays[ytest.index]

rf = RandomForestClassifier(n_estimators=100, n_jobs=cpu_count(), random_state=RS).fit(xtrain_docvec, ytrain)
prediction = rf.predict(xtest_docvec)
f1_score(ytest, prediction)
# Out:
# 0.9134111961337092

# %%
print_conf_matrix(ytest, prediction)

# %% [markdown]
# ## Summarization (BoW, W2V)

# %%
# for w2v model
def get_cosine_sim(tokens, model, arr: np.ndarray) -> List[float]:
    cosine_vals = []
    for word in tokens:
        try:
            word_vector = model.wv[word]
            cosine_vals.append(cosine(word_vector, arr))
        except KeyError:
            cosine_vals.append(0)
    return cosine_vals


def summarize(series: pd.Series, featurizer_type: str) -> None:
    assert featurizer_type in ['bow', 'w2v']

    tokenized_text_clean = np.array(series.text_clean.split())

    if featurizer_type == 'bow':
        sentence_vector = bow.toarray()[series.name]
        selected_indices = np.where(sentence_vector > np.mean(sentence_vector))[0]

        selected_words = bow_vectorizer.get_feature_names_out()[selected_indices]
        mask = np.in1d(tokenized_text_clean, selected_words)
        selected_words_ordered = tokenized_text_clean[mask]
    else:
        cosine_vals = get_cosine_sim(tokenized_text_clean, w2v_model, wordvec_arrays[series.name])
        selected_indices = np.where(cosine_vals > np.mean(cosine_vals))[0]

        selected_words_ordered = tokenized_text_clean[selected_indices]

    summarized_text = ' '.join(selected_words_ordered.tolist())
    print(f"====> Original <====\n{series.text}\n\n====> Summarized <====\n{summarized_text}")

# %%
summarize(df.iloc[5], 'bow')
# Out:
# ====> Original <====
# Tune in to the Alternate Current Radio Network (ACR) for another LIVE broadcast of  The Boiler Room tonight 6:00 PM PST | 8:00 PM CST | 9:00 PM EST for this special broadcast. Join us for uncensored, uninterruptible talk radio, custom-made for bar fly philosophers, misguided moralists, masochists, street corner evangelists, media-maniacs, savants, political animals and otherwise lovable rascals.Join ACR hosts Hesher and Spore along with Funk Soul, Stewart Howe (ACR/21WIRE contributor) and Andy Nowicki, author of Conspiracy, Compliance, Control & Defiance, for the hundred and second episode of BOILER ROOM. Turn it up, tune in and hang with the ACR Brain-Trust for this weeks boil downs and analysis on the London terror events, proof that the sad failure of identity politics that can and does lead young people to an early death, the voracity of Dr. Phil s alleged expos  on systemic pedophile rings in the circles of powerful elites and the usual gnashing of the teeth of the political animals in the social reject club.Listen to  Boiler Room #102   Tales From The Black Pill  on Spreaker.Direct Download Episode #102Please like and share the program and visit our donate page to get involved!Reference Links:
#
# ====> Summarized <====
# current network another special street political conspiracy control hundred second london terror failure politics people alleged powerful political social program

# %%
summarize(df.iloc[5], 'w2v')
# Out:
# ====> Original <====
# Tune in to the Alternate Current Radio Network (ACR) for another LIVE broadcast of  The Boiler Room tonight 6:00 PM PST | 8:00 PM CST | 9:00 PM EST for this special broadcast. Join us for uncensored, uninterruptible talk radio, custom-made for bar fly philosophers, misguided moralists, masochists, street corner evangelists, media-maniacs, savants, political animals and otherwise lovable rascals.Join ACR hosts Hesher and Spore along with Funk Soul, Stewart Howe (ACR/21WIRE contributor) and Andy Nowicki, author of Conspiracy, Compliance, Control & Defiance, for the hundred and second episode of BOILER ROOM. Turn it up, tune in and hang with the ACR Brain-Trust for this weeks boil downs and analysis on the London terror events, proof that the sad failure of identity politics that can and does lead young people to an early death, the voracity of Dr. Phil s alleged expos  on systemic pedophile rings in the circles of powerful elites and the usual gnashing of the teeth of the political animals in the social reject club.Listen to  Boiler Room #102   Tales From The Black Pill  on Spreaker.Direct Download Episode #102Please like and share the program and visit our donate page to get involved!Reference Links:
#
# ====> Summarized <====
# alternate network tonight special misguided street corner animal otherwise stewart contributor author conspiracy compliance control defiance hundred second analysis london terror failure identity politics people alleged systemic pedophile circle powerful animal social reject download program donate

# %% [markdown]
# ## Named Entity Recognition

# %%
tokenizer = AutoTokenizer.from_pretrained("dslim/bert-base-NER")
model = AutoModelForTokenClassification.from_pretrained("dslim/bert-base-NER")

nlp = pipeline("ner", model=model, tokenizer=tokenizer)

ner_results = nlp(df.iloc[15].text)
print(ner_results)
# Out:
# [{'entity': 'B-ORG', 'score': 0.99609154, 'index': 1, 'word': 'WA', 'start': 0, 'end': 2}, {'entity': 'I-ORG', 'score': 0.9932029, 'index': 2, 'word': '##S', 'start': 2, 'end': 3}, {'entity': 'I-ORG', 'score': 0.9957248, 'index': 3, 'word': '##H', 'start': 3, 'end': 4}, {'entity': 'I-ORG', 'score': 0.98575944, 'index': 4, 'word': '##ING', 'start': 4, 'end': 7}, {'entity': 'I-ORG', 'score': 0.99841344, 'index': 5, 'word': '##TO', 'start': 7, 'end': 9}, {'entity': 'I-ORG', 'score': 0.99779934, 'index': 6, 'word': '##N', 'start': 9, 'end': 10}, {'entity': 'B-ORG', 'score': 0.9993038, 'index': 8, 'word': 'Re', 'start': 12, 'end': 14}, {'entity': 'I-ORG', 'score': 0.99872893, 'index': 9, 'word': '##uters', 'start': 14, 'end': 19}, {'entity': 'B-LOC', 'score': 0.9996082, 'index': 12, 'word': 'U', 'start': 23, 'end': 24}, {'entity': 'I-LOC', 'score': 0.9978655, 'index': 13, 'word': '.', 'start': 24, 'end': 25}, {'entity': 'I-LOC', 'score': 0.99869174, 'index': 14, 'word': 'S', 'start': 25, 'end': 26}, {'entity': 'I-LOC', 'score': 0.9873137, 'index': 15, 'word': '.', 'start': 26, 'end': 27}, {'entity': 'B-PER', 'score': 0.9997439, 'index': 20, 'word': 'Mike', 'start': 49, 'end': 53}, {'entity': 'I-PER', 'score': 0.99956733, 'index': 21, 'word': 'Pen', 'start': 54, 'end': 57}, {'entity': 'I-PER', 'score': 0.99798846, 'index': 22, 'word': '##ce', 'start': 57, 'end': 59}, {'entity': 'B-LOC', 'score': 0.99972993, 'index': 34, 'word': 'Cuba', 'start': 103, 'end': 107}, {'entity': 'B-PER', 'score': 0.9958697, 'index': 39, 'word': 'Fi', 'start': 127, 'end': 129}, {'entity': 'B-PER', 'score': 0.996786, 'index': 40, 'word': '##del', 'start': 129, 'end': 132}, {'entity': 'I-PER', 'score': 0.9963381, 'index': 41, 'word': 'Castro', 'start': 133, 'end': 139}, {'entity': 'B-PER', 'score': 0.9985911, 'index': 48, 'word': 'Castro', 'start': 153, 'end': 159}, {'entity': 'B-MISC', 'score': 0.9995691, 'index': 64, 'word': 'Cuban', 'start': 218, 'end': 223}, {'entity': 'B-LOC', 'score': 0.99927646, 'index': 71, 'word': 'Cuba', 'start': 257, 'end': 261}, {'entity': 'B-ORG', 'score': 0.8698222, 'index': 73, 'word': 'Viva', 'start': 263, 'end': 267}, {'entity': 'I-ORG', 'score': 0.9790125, 'index': 74, 'word': 'Cuba', 'start': 268, 'end': 272}, {'entity': 'I-ORG', 'score': 0.9979285, 'index': 75, 'word': 'Li', 'start': 273, 'end': 275}, {'entity': 'I-ORG', 'score': 0.99756014, 'index': 76, 'word': '##bre', 'start': 275, 'end': 278}, {'entity': 'B-PER', 'score': 0.9651537, 'index': 79, 'word': 'Pen', 'start': 281, 'end': 284}, {'entity': 'I-PER', 'score': 0.90520126, 'index': 80, 'word': '##ce', 'start': 284, 'end': 286}]

# %%
df.iloc[15].text
# Out:
# 'WASHINGTON (Reuters) - U.S. Vice President-elect Mike Pence said on Saturday that “new hope dawns” for Cuba after the death of Fidel Castro. “The tyrant Castro is dead. New hope dawns. We will stand with the oppressed Cuban people for a free and democratic Cuba. Viva Cuba Libre!” Pence said on Twitter. '

# %%
su = "reuters predicted oppose reviewing reform spokesman contrary assertion career anyway individual become determine control defection wisconsin johnson publicly stated opposes approve defecting critical delivered speech october threatened nation democracy speech seeking reelection expires critical reelection arizona overheard nearby microphone become television station microphone recorded alabama sexual misconduct allegation december special intentionally unelectable arizona anemic caught purposely favorite"

# %%
ner_results = nlp(su)
print(ner_results)
# Out:
# [{'entity': 'B-ORG', 'score': 0.99411243, 'index': 1, 'word': 're', 'start': 0, 'end': 2}]
